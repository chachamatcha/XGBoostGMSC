# %% [markdown]
# # XGBOOST

# %% [markdown]
# ### Import Necessary and Relevant Packages

# %%
# %matplotlib inline

from IPython.display import display
from IPython.display import Image

import warnings
import os
warnings.filterwarnings('ignore')
from time import time
t00=time()

import theano
theano.config.optimizer='fast_compile'


import pandas as pd
import numpy as np
import xgboost as xgb
from hyperopt import fmin, hp, STATUS_OK, Trials, rand, anneal, tpe, mix, partial
from hp_gpsmbo import hpsuggest_ei
from hp_gpsmbo import hpsuggest_ucb
import matplotlib.pylab as plt
# Out:
# Mapped name None to device cuda: GeForce GTX 980 Ti
# PCI Bus ID: 0000:01:00.0
# Using cuDNN version 5105 on context None
# /home/jd/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Import Data

# %%
credit_training = pd.read_csv('cs-training.csv')
credit_training_filled=credit_training.fillna(credit_training.median())
credit_training = credit_training.drop('Unnamed: 0', 1)

credit_test = pd.read_csv('cs-test.csv')
credit_test_filled=credit_test.fillna(credit_test.median())
credit_test = credit_test.drop('Unnamed: 0', 1)
credit_test = credit_test.drop('SeriousDlqin2yrs', 1)

y_training=credit_training['SeriousDlqin2yrs']
X_training=credit_training.loc[:,'RevolvingUtilizationOfUnsecuredLines':'NumberOfDependents']

y_training_filled=credit_training_filled['SeriousDlqin2yrs']
X_training_filled=credit_training_filled.loc[:,'RevolvingUtilizationOfUnsecuredLines':'NumberOfDependents']

X_test=credit_test.loc[:,'RevolvingUtilizationOfUnsecuredLines':'NumberOfDependents']

# %% [markdown]
# ### Box-Cox Transformations

# %%
from scipy import stats

# training
X_training_BC=credit_training.loc[:,'RevolvingUtilizationOfUnsecuredLines':'NumberOfDependents']

x = X_training['age']+.0001
xt, _ = stats.boxcox(x)
X_training_BC['age']=xt

x = X_training['MonthlyIncome']+.0001
xt, _ = stats.boxcox(x)
X_training_BC['MonthlyIncome']=xt

x = X_training['RevolvingUtilizationOfUnsecuredLines']+.0001
xt, _ = stats.boxcox(x)
X_training_BC['RevolvingUtilizationOfUnsecuredLines']=xt



# test
X_test_BC=credit_test.loc[:,'RevolvingUtilizationOfUnsecuredLines':'NumberOfDependents']

x = X_test['age']+.0001
xt, _ = stats.boxcox(x)
X_test_BC['age']=xt

x = X_test['MonthlyIncome']+.0001
xt, _ = stats.boxcox(x)
X_test_BC['MonthlyIncome']=xt

x = X_test['RevolvingUtilizationOfUnsecuredLines']+.0001
xt, _ = stats.boxcox(x)
X_test_BC['RevolvingUtilizationOfUnsecuredLines']=xt

# %% [markdown]
# ### Benchmark default hyperparameters

# %%
# init xgboost params
paramsDefault={'reg_alpha': 0,
               'colsample_bytree': 1,
               'colsample_bylevel': 1,
               'scale_pos_weight': 1,
               'learning_rate': 0.1,
               'base_score': .5,
               'n_estimators': 100,
               'subsample': 1,
               'reg_lambda': 1,
               'min_child_weight': 1,
               'eval_metric':'auc',
               'objective': 'binary:logistic',
               'max_depth': 3,
               'gamma': 0}

# load data into dmatrix
xgtrain = xgb.DMatrix(X_training, label=y_training)
xgtrain_bc = xgb.DMatrix(X_training_BC, label=y_training)

# 3-fold CV for both feature sets
modelcv=xgb.cv(paramsDefault, xgtrain, 100, nfold=3)
modelcv_bc=xgb.cv(paramsDefault, xgtrain_bc, 100, nfold=3)

# 10-fold CV for both feature sets
modelcv10=xgb.cv(paramsDefault, xgtrain, 100, nfold=10)
modelcv_bc10=xgb.cv(paramsDefault, xgtrain_bc, 100, nfold=10)

# print cv results
print '3-fold CV'
print 'Cross-Validation Results for NON-Box-Cox Transformed'
print modelcv.loc[99]
print '-'*57
print 'Cross-Validation Results for Box-Cox Transformed'
print modelcv_bc.loc[99]
print '#'*57
print '10-fold CV'
print 'Cross-Validation Results for NON-Box-Cox Transformed'
print modelcv10.loc[99]
print '-'*57
print 'Cross-Validation Results for Box-Cox Transformed'
print modelcv_bc10.loc[99]
# Out:
# 3-fold CV
# Cross-Validation Results for NON-Box-Cox Transformed
# test-auc-mean     0.864002
# test-auc-std      0.002083
# train-auc-mean    0.870174
# train-auc-std     0.001212
# Name: 99, dtype: float64
# ---------------------------------------------------------
# Cross-Validation Results for Box-Cox Transformed
# test-auc-mean     0.863947
# test-auc-std      0.002122
# train-auc-mean    0.870002
# train-auc-std     0.001127
# Name: 99, dtype: float64
# #########################################################
# 10-fold CV
# Cross-Validation Results for NON-Box-Cox Transformed
# test-auc-mean     0.864685
# test-auc-std      0.008702
# train-auc-mean    0.869142
# train-auc-std     0.000999
# Name: 99, dtype: float64
# ---------------------------------------------------------
# Cross-Validation Results for Box-Cox Transformed
# test-auc-mean     0.864683
# test-auc-std      0.008704
# train-auc-mean    0.869140
# train-auc-std     0.000999
# Name: 99, dtype: float64

# %% [markdown]
# ### Fit benchmark models

# %%
#fit
model=xgb.train(paramsDefault, xgtrain, 100)
modelbc=xgb.train(paramsDefault, xgtrain_bc, 100)

# %% [markdown]
# ### Plot Tree 1

# %%
#plot tree
xgb.to_graphviz(model,num_trees=0)

# %% [markdown]
# ### Plot Tree 2

# %%
#plot tree
xgb.to_graphviz(model,num_trees=1)

# %% [markdown]
# ### Plot Tree 3

# %%
#plot tree
xgb.to_graphviz(model,num_trees=2)

# %% [markdown]
# ### Plot Tree 4

# %%
#plot tree
xgb.to_graphviz(model,num_trees=3)

# %% [markdown]
# ### Make and Store Predictions for Submission

# %%
# make dmatrix
xgtest = xgb.DMatrix(X_test)

# predict and store unmodified X
pred=model.predict(xgtest)
submission = pd.DataFrame()
submission['Probability'] = pred
submission.to_csv('sub_v.csv')


# make dmatrix 
xgtest_bc = xgb.DMatrix(X_test_BC)

# predict and store Box-cox X
pred=modelbc.predict(xgtest_bc)
submission = pd.DataFrame()
submission['Probability'] = pred
submission.to_csv('sub_v_BC.csv')

# %%
print
print 'XGBoost, No Independent Variable Transformation'
XGBoost_url1 = 'http://i.imgur.com/Gymp03Q.jpg'
Image(url=XGBoost_url1)
# Out:
# XGBoost, No Independent Variable Transformation
# <img src="http://i.imgur.com/Gymp03Q.jpg"/>

# %%
print
print 'XGBoost, Box-Cox Independent Variable Transformation'
XGBoost_url2 = 'http://i.imgur.com/djgwXL3.jpg'
Image(url=XGBoost_url2)
# Out:
# XGBoost, Box-Cox Independent Variable Transformation
# <img src="http://i.imgur.com/djgwXL3.jpg"/>

# %% [markdown]
# ## Hyperopt

# %%
def hyperopt_train_test(params):
    params['eta']=.1
    try:
        modelcv=xgb.cv(params, xgtrain, 10000, nfold=3, early_stopping_rounds=75)
    except:
        return .85
    return modelcv.loc[np.size(modelcv,0)-1][0]

def hyperopt_train_test_BC(params):
    params['eta']=.1
    try:
        modelcv=xgb.cv(params, xgtrain_bc, 10000, nfold=3, early_stopping_rounds=75)
    except:
        return .85
    return modelcv.loc[np.size(modelcv,0)-1][0]

# %% [markdown]
# ### Functions to be minimized

# %%
xs=[]
ys=[]          
best = .5
i=0
clfs=pd.DataFrame()   
def f(params):
    global i
    global best
    global clfs
    auc = hyperopt_train_test(params)

    i=i+1
    print 'Trial: ',i, ' AUC: ',auc

    xs.append(i)
    ys.append(auc)

    if auc > best:
        best = auc
        print 'New best:', auc
        print params
        print 'Trial: ', i
        print
        df = pd.DataFrame([[params, auc]], columns=['clf','score'])
        clfs=clfs.append(df)
        clfs.to_csv('clfscompare.csv')
        print time()-t00
        
    return {'loss': -auc, 'status': STATUS_OK}



  
def f_BC(params):
    global i
    global best
    global clfs
    auc = hyperopt_train_test_BC(params)

    i=i+1
    print 'Trial: ',i, ' AUC: ',auc

    xs.append(i)
    ys.append(auc)

    if auc > best:
        best = auc
        print 'New best:', auc
        print params
        print 'Trial: ', i
        print
        df = pd.DataFrame([[params, auc]], columns=['clf','score'])
        clfs=clfs.append(df)
        clfs.to_csv('clfscomparebc.csv')
        print time()-t00
        
    return {'loss': -auc, 'status': STATUS_OK}

# %% [markdown]
# ### Space to explore

# %%
space4xg = {"max_depth": hp.choice('max_depth', range(4,15)),
          "min_child_weight": hp.choice('min_child_weight', range(1,270)),
          "gamma": hp.uniform('gamma',0,3),
          "colsample_bytree": hp.uniform('colsample_bytree', .95,1.0),
          "subsample": hp.uniform('subsample', .2,.9999),
          "lambda": hp.uniform('reg_lambda',0,52.7),
          "alpha": hp.uniform('reg_alpha',0,27),
          "scale_pos_weight":hp.uniform('scale_pos_weight',0.01,100),
          "base_score":hp.uniform('base_score',0.1,.9999),
          'colsample_bylevel':hp.uniform('colsample_bylevel', .1,.9999),
          'objective': hp.choice('objective', ['binary:logistic','binary:logitraw']),
          'eval_metric': hp.choice('eval_metric', ['auc'])}

# %% [markdown]
# ### Initiate optimization for non-transform

# %%
trials = Trials()

# warm up
rng=np.random.RandomState(seed=0)
bt = fmin(f, space4xg, algo=rand.suggest , max_evals=15, trials=trials, rstate=rng)

bt = fmin(f, space4xg, algo=hpsuggest_ucb.suggest , max_evals=125, trials=trials,rstate=rng)

paramsBO=clfs.clf.iloc[-1]

print 'Best Estimator: ', paramsBO
# Out:
# Trial:  1  AUC:  0.863223
# New best: 0.863223
# {'colsample_bytree': 0.9850734317541101, 'eval_metric': 'auc', 'colsample_bylevel': 0.8615939601152381, 'scale_pos_weight': 68.57437462792714, 'base_score': 0.8169586947984625, 'subsample': 0.5887892536849382, 'eta': 0.1, 'min_child_weight': 240, 'objective': 'binary:logitraw', 'alpha': 5.281103074380008, 'max_depth': 13, 'gamma': 0.5414408921698582, 'lambda': 51.93985786986626}
# Trial:  1
#
# 90.8750960827
# Trial:  2  AUC:  0.861203333333
# Trial:  3  AUC:  0.860710666667
# Trial:  4  AUC:  0.864993
# New best: 0.864993
# {'colsample_bytree': 0.9704286505924608, 'eval_metric': 'auc', 'colsample_bylevel': 0.8336444106510245, 'scale_pos_weight': 5.799205390916088, 'base_score': 0.3903688930191075, 'subsample': 0.6229005244861532, 'eta': 0.1, 'min_child_weight': 156, 'objective': 'binary:logitraw', 'alpha': 5.169572333578733, 'max_depth': 9, 'gamma': 1.9262238318618334, 'lambda': 18.03833777097961}
# Trial:  4
#
# 137.042526007
# Trial:  5  AUC:  0.86221
# Trial:  6  AUC:  0.864716333333
# Trial:  7  AUC:  0.863026333333
# Trial:  8  AUC:  0.864054666667
# Trial:  9  AUC:  0.861700333333
# Trial:  10  AUC:  0.863139
# Trial:  11  AUC:  0.863364333333
# Trial:  12  AUC:  0.864312
# Trial:  13  AUC:  0.864583
# Trial:  14  AUC:  0.864611666667
# Trial:  15  AUC:  0.86498
# Trial:  16  AUC:  0.863009
# (<class 'hp_gpsmbo.kernels.SqExp'>, False, 0) [(<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc490>, slice(0, 1, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbcbd0>, slice(1, 2, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc410>, slice(2, 3, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc390>, slice(4, 5, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbca50>, slice(7, 8, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc250>, slice(8, 9, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc9d0>, slice(9, 10, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc0d0>, slice(10, 11, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f82dbc950>, slice(11, 12, None))]
# 140254352493392 [(<hp_gpsmbo.kernels.ChoiceN object at 0x7f8f82dbcb50>, slice(3, 4, None))]
# 140254352493264 [(<hp_gpsmbo.kernels.ChoiceN object at 0x7f8f82dbcad0>, slice(5, 6, None))]
# 140254352491280 [(<hp_gpsmbo.kernels.ChoiceN object at 0x7f8f82dbc310>, slice(6, 7, None))]
# starting fit
# UCB: Best after 16 trials: -0.864993
# Trial:  17  AUC:  0.865273
# New best: 0.865273
# {'colsample_bytree': 0.9892487246341722, 'eval_metric': 'auc', 'colsample_bylevel': 0.5671836423273958, 'scale_pos_weight': 7.861998600553948, 'base_score': 0.8479284634872454, 'subsample': 0.5196704252240281, 'eta': 0.1, 'min_child_weight': 144, 'objective': 'binary:logistic', 'alpha': 9.42486182479168, 'max_depth': 6, 'gamma': 0.5919886171715913, 'lambda': 38.53098428299787}
# Trial:  17
#
# 370.851691008
# starting fit
# UCB: Best after 17 trials: -0.865273
# Trial:  18  AUC:  0.864986333333
# starting fit
# UCB: Best after 18 trials: -0.865273
# Trial:  19  AUC:  0.864513666667
# starting fit
# UCB: Best after 19 trials: -0.865273
# Trial:  20  AUC:  0.865398666667
# New best: 0.865398666667
# {'colsample_bytree': 0.9790169164045927, 'eval_metric': 'auc', 'colsample_bylevel': 0.5994888247708211, 'scale_pos_weight': 5.460507426513036, 'base_score': 0.8565645513441948, 'subsample': 0.73010116113577, 'eta': 0.1, 'min_child_weight': 181, 'objective': 'binary:logistic', 'alpha': 11.769292868242143, 'max_depth': 12, 'gamma': 1.2000467880110897, 'lambda': 52.7}
# Trial:  20
#
# 420.689429998
# starting fit
# UCB: Best after 20 trials: -0.865399
# Trial:  21  AUC:  0.865976666667
# New best: 0.865976666667
# {'colsample_bytree': 0.9840359231768908, 'eval_metric': 'auc', 'colsample_bylevel': 0.5109305896173985, 'scale_pos_weight': 1.359850999193668, 'base_score': 0.8873161823691376, 'subsample': 0.6727538438083611, 'eta': 0.1, 'min_child_weight': 61, 'objective': 'binary:logistic', 'alpha': 12.522235326206593, 'max_depth': 5, 'gamma': 1.1620884865711494, 'lambda': 51.56105868007416}
# Trial:  21
#
# 448.830065012
# starting fit
# UCB: Best after 21 trials: -0.865977
# Trial:  22  AUC:  0.5
# starting fit
# UCB: Best after 22 trials: -0.865977
# Trial:  23  AUC:  0.863584
# starting fit
# UCB: Best after 23 trials: -0.865977
# Trial:  24  AUC:  0.864778333333
# starting fit
# UCB: Best after 24 trials: -0.865977
# Trial:  25  AUC:  0.864128666667
# starting fit
# UCB: Best after 25 trials: -0.865977
# Trial:  26  AUC:  0.5
# starting fit
# UCB: Best after 26 trials: -0.865977
# Trial:  27  AUC:  0.5
# starting fit
# UCB: Best after 27 trials: -0.865977
# Trial:  28  AUC:  0.864177
# starting fit
# UCB: Best after 28 trials: -0.865977
# Trial:  29  AUC:  0.5
# starting fit
# UCB: Best after 29 trials: -0.865977
# Trial:  30  AUC:  0.865560666667
# starting fit
# UCB: Best after 30 trials: -0.865977
# Trial:  31  AUC:  0.862863333333
# starting fit
# UCB: Best after 31 trials: -0.865977
# Trial:  32  AUC:  0.863999333333
# starting fit
# UCB: Best after 32 trials: -0.865977
# Trial:  33  AUC:  0.864161333333
# starting fit
# UCB: Best after 33 trials: -0.865977
# Trial:  34  AUC:  0.865272666667
# starting fit
# UCB: Best after 34 trials: -0.865977
# Trial:  35  AUC:  0.865674666667
# starting fit
# UCB: Best after 35 trials: -0.865977
# Trial:  36  AUC:  0.5
# starting fit
# UCB: Best after 36 trials: -0.865977
# Trial:  37  AUC:  0.863462
# starting fit
# UCB: Best after 37 trials: -0.865977
# Trial:  38  AUC:  0.5
# starting fit
# UCB: Best after 38 trials: -0.865977
# Trial:  39  AUC:  0.863029666667
# starting fit
# UCB: Best after 39 trials: -0.865977
# Trial:  40  AUC:  0.865952666667
# starting fit
# UCB: Best after 40 trials: -0.865977
# Trial:  41  AUC:  0.865699
# starting fit
# UCB: Best after 41 trials: -0.865977
# Trial:  42  AUC:  0.865840666667
# starting fit
# UCB: Best after 42 trials: -0.865977
# Trial:  43  AUC:  0.5
# starting fit
# UCB: Best after 43 trials: -0.865977
# Trial:  44  AUC:  0.865539
# starting fit
# UCB: Best after 44 trials: -0.865977
# Trial:  45  AUC:  0.862943
# starting fit
# UCB: Best after 45 trials: -0.865977
# Trial:  46  AUC:  0.865014666667
# starting fit
# UCB: Best after 46 trials: -0.865977
# Trial:  47  AUC:  0.865215
# starting fit
# UCB: Best after 47 trials: -0.865977
# Trial:  48  AUC:  0.5
# starting fit
# UCB: Best after 48 trials: -0.865977
# Trial:  49  AUC:  0.865780333333
# starting fit
# UCB: Best after 49 trials: -0.865977
# Trial:  50  AUC:  0.864704
# starting fit
# UCB: Best after 50 trials: -0.865977
# Trial:  51  AUC:  0.862082
# starting fit
# UCB: Best after 51 trials: -0.865977
# Trial:  52  AUC:  0.859756333333
# starting fit
# UCB: Best after 52 trials: -0.865977
# Trial:  53  AUC:  0.865426333333
# starting fit
# UCB: Best after 53 trials: -0.865977
# Trial:  54  AUC:  0.865169333333
# starting fit
# UCB: Best after 54 trials: -0.865977
# Trial:  55  AUC:  0.5
# starting fit
# UCB: Best after 55 trials: -0.865977
# Trial:  56  AUC:  0.865857666667
# starting fit
# UCB: Best after 56 trials: -0.865977
# Trial:  57  AUC:  0.864583333333
# starting fit
# UCB: Best after 57 trials: -0.865977
# Trial:  58  AUC:  0.863075
# starting fit
# UCB: Best after 58 trials: -0.865977
# Trial:  59  AUC:  0.864555333333
# starting fit
# UCB: Best after 59 trials: -0.865977
# Trial:  60  AUC:  0.865952666667
# starting fit
# UCB: Best after 60 trials: -0.865977
# Trial:  61  AUC:  0.5
# starting fit
# UCB: Best after 61 trials: -0.865977
# Trial:  62  AUC:  0.865534
# starting fit
# UCB: Best after 62 trials: -0.865977
# Trial:  63  AUC:  0.865115333333
# starting fit
# UCB: Best after 63 trials: -0.865977
# Trial:  64  AUC:  0.864841666667
# starting fit
# UCB: Best after 64 trials: -0.865977
# Trial:  65  AUC:  0.864731
# starting fit
# UCB: Best after 65 trials: -0.865977
# Trial:  66  AUC:  0.863767
# starting fit
# UCB: Best after 66 trials: -0.865977
# Trial:  67  AUC:  0.862997
# starting fit
# UCB: Best after 67 trials: -0.865977
# Trial:  68  AUC:  0.866173333333
# New best: 0.866173333333
# {'colsample_bytree': 0.9670832715520193, 'eval_metric': 'auc', 'colsample_bylevel': 0.34132429922429275, 'scale_pos_weight': 1.9224124618275635, 'base_score': 0.5119055666963369, 'subsample': 0.6454263317106109, 'eta': 0.1, 'min_child_weight': 12, 'objective': 'binary:logistic', 'alpha': 16.74386169974998, 'max_depth': 7, 'gamma': 1.4600489917112498, 'lambda': 52.7}
# Trial:  68
#
# 1360.30561495
# starting fit
# UCB: Best after 68 trials: -0.866173
# Trial:  69  AUC:  0.859708666667
# starting fit
# UCB: Best after 69 trials: -0.866173
# Trial:  70  AUC:  0.5
# starting fit
# UCB: Best after 70 trials: -0.866173
# Trial:  71  AUC:  0.863747
# starting fit
# UCB: Best after 71 trials: -0.866173
# Trial:  72  AUC:  0.864591333333
# starting fit
# UCB: Best after 72 trials: -0.866173
# Trial:  73  AUC:  0.864879666667
# starting fit
# UCB: Best after 73 trials: -0.866173
# Trial:  74  AUC:  0.5
# starting fit
# UCB: Best after 74 trials: -0.866173
# Trial:  75  AUC:  0.5
# starting fit
# UCB: Best after 75 trials: -0.866173
# Trial:  76  AUC:  0.864390666667
# starting fit
# UCB: Best after 76 trials: -0.866173
# Trial:  77  AUC:  0.864760666667
# starting fit
# UCB: Best after 77 trials: -0.866173
# Trial:  78  AUC:  0.862860666667
# starting fit
# UCB: Best after 78 trials: -0.866173
# Trial:  79  AUC:  0.864953333333
# starting fit
# UCB: Best after 79 trials: -0.866173
# Trial:  80  AUC:  0.865140333333
# starting fit
# UCB: Best after 80 trials: -0.866173
# Trial:  81  AUC:  0.863657666667
# starting fit
# UCB: Best after 81 trials: -0.866173
# Trial:  82  AUC:  0.865399333333
# starting fit
# UCB: Best after 82 trials: -0.866173
# Trial:  83  AUC:  0.864816
# starting fit
# UCB: Best after 83 trials: -0.866173
# Trial:  84  AUC:  0.865967
# starting fit
# UCB: Best after 84 trials: -0.866173
# Trial:  85  AUC:  0.86454
# starting fit
# UCB: Best after 85 trials: -0.866173
# Trial:  86  AUC:  0.864837666667
# starting fit
# UCB: Best after 86 trials: -0.866173
# Trial:  87  AUC:  0.5
# starting fit
# UCB: Best after 87 trials: -0.866173
# Trial:  88  AUC:  0.5
# starting fit
# UCB: Best after 88 trials: -0.866173
# Trial:  89  AUC:  0.865600333333
# starting fit
# UCB: Best after 89 trials: -0.866173
# Trial:  90  AUC:  0.865212
# starting fit
# UCB: Best after 90 trials: -0.866173
# Trial:  91  AUC:  0.5
# starting fit
# UCB: Best after 91 trials: -0.866173
# Trial:  92  AUC:  0.865364
# starting fit
# UCB: Best after 92 trials: -0.866173
# Trial:  93  AUC:  0.736466
# starting fit
# UCB: Best after 93 trials: -0.866173
# Trial:  94  AUC:  0.85
# starting fit
# UCB: Best after 94 trials: -0.866173
# Trial:  95  AUC:  0.86097
# starting fit
# UCB: Best after 95 trials: -0.866173
# Trial:  96  AUC:  0.864781333333
# starting fit
# UCB: Best after 96 trials: -0.866173
# Trial:  97  AUC:  0.863970666667
# starting fit
# UCB: Best after 97 trials: -0.866173
# Trial:  98  AUC:  0.865213
# starting fit
# UCB: Best after 98 trials: -0.866173
# Trial:  99  AUC:  0.864821
# starting fit
# UCB: Best after 99 trials: -0.866173
# Trial:  100  AUC:  0.864441666667
# starting fit
# UCB: Best after 100 trials: -0.866173
# Trial:  101  AUC:  0.864004666667
# starting fit
# UCB: Best after 101 trials: -0.866173
# Trial:  102  AUC:  0.861550666667
# starting fit
# UCB: Best after 102 trials: -0.866173
# Trial:  103  AUC:  0.865097333333
# starting fit
# UCB: Best after 103 trials: -0.866173
# Trial:  104  AUC:  0.5
# starting fit
# UCB: Best after 104 trials: -0.866173
# Trial:  105  AUC:  0.863291
# starting fit
# UCB: Best after 105 trials: -0.866173
# Trial:  106  AUC:  0.865085
# starting fit
# UCB: Best after 106 trials: -0.866173
# Trial:  107  AUC:  0.864555333333
# starting fit
# UCB: Best after 107 trials: -0.866173
# Trial:  108  AUC:  0.863692
# starting fit
# UCB: Best after 108 trials: -0.866173
# Trial:  109  AUC:  0.5
# starting fit
# UCB: Best after 109 trials: -0.866173
# Trial:  110  AUC:  0.865743666667
# starting fit
# UCB: Best after 110 trials: -0.866173
# Trial:  111  AUC:  0.864480666667
# starting fit
# UCB: Best after 111 trials: -0.866173
# Trial:  112  AUC:  0.865387
# starting fit
# UCB: Best after 112 trials: -0.866173
# Trial:  113  AUC:  0.5
# starting fit
# UCB: Best after 113 trials: -0.866173
# Trial:  114  AUC:  0.864988666667
# starting fit
# UCB: Best after 114 trials: -0.866173
# Trial:  115  AUC:  0.864351
# starting fit
# UCB: Best after 115 trials: -0.866173
# Trial:  116  AUC:  0.5
# starting fit
# UCB: Best after 116 trials: -0.866173
# Trial:  117  AUC:  0.8643
# starting fit
# UCB: Best after 117 trials: -0.866173
# Trial:  118  AUC:  0.864919666667
# starting fit
# UCB: Best after 118 trials: -0.866173
# Trial:  119  AUC:  0.865139333333
# starting fit
# UCB: Best after 119 trials: -0.866173
# Trial:  120  AUC:  0.864341
# starting fit
# UCB: Best after 120 trials: -0.866173
# Trial:  121  AUC:  0.865922
# starting fit
# UCB: Best after 121 trials: -0.866173
# Trial:  122  AUC:  0.863756333333
# starting fit
# UCB: Best after 122 trials: -0.866173
# Trial:  123  AUC:  0.854896666667
# starting fit
# UCB: Best after 123 trials: -0.866173
# Trial:  124  AUC:  0.862484666667
# starting fit
# UCB: Best after 124 trials: -0.866173
# Trial:  125  AUC:  0.862385666667
# Best Estimator:  {'colsample_bytree': 0.9670832715520193, 'eval_metric': 'auc', 'colsample_bylevel': 0.34132429922429275, 'scale_pos_weight': 1.9224124618275635, 'base_score': 0.5119055666963369, 'subsample': 0.6454263317106109, 'eta': 0.1, 'min_child_weight': 12, 'objective': 'binary:logistic', 'alpha': 16.74386169974998, 'max_depth': 7, 'gamma': 1.4600489917112498, 'lambda': 52.7}

# %% [markdown]
# ### Initiate Box-COx transformed fit optimization

# %%
# reset
xs=[]
ys=[]          
best = .5
i=0
clfs=pd.DataFrame() 


trials_BC = Trials()

# warm up
rng=np.random.RandomState(seed=0)
btBC = fmin(f_BC, space4xg, algo=rand.suggest , max_evals=15, trials=trials_BC, rstate=rng)

btBC = fmin(f_BC, space4xg, algo=hpsuggest_ucb.suggest , max_evals=125, trials=trials_BC,rstate=rng)

paramsBOBC=clfs.clf.iloc[-1]

print 'Best Estimator: ', paramsBOBC
# Out:
# Trial:  1  AUC:  0.863285
# New best: 0.863285
# {'colsample_bytree': 0.9850734317541101, 'eval_metric': 'auc', 'colsample_bylevel': 0.8615939601152381, 'scale_pos_weight': 68.57437462792714, 'base_score': 0.8169586947984625, 'subsample': 0.5887892536849382, 'eta': 0.1, 'min_child_weight': 240, 'objective': 'binary:logitraw', 'alpha': 5.281103074380008, 'max_depth': 13, 'gamma': 0.5414408921698582, 'lambda': 51.93985786986626}
# Trial:  1
#
# 2352.47539687
# Trial:  2  AUC:  0.861242
# Trial:  3  AUC:  0.860682333333
# Trial:  4  AUC:  0.864993666667
# New best: 0.864993666667
# {'colsample_bytree': 0.9704286505924608, 'eval_metric': 'auc', 'colsample_bylevel': 0.8336444106510245, 'scale_pos_weight': 5.799205390916088, 'base_score': 0.3903688930191075, 'subsample': 0.6229005244861532, 'eta': 0.1, 'min_child_weight': 156, 'objective': 'binary:logitraw', 'alpha': 5.169572333578733, 'max_depth': 9, 'gamma': 1.9262238318618334, 'lambda': 18.03833777097961}
# Trial:  4
#
# 2399.307019
# Trial:  5  AUC:  0.861948333333
# Trial:  6  AUC:  0.864715666667
# Trial:  7  AUC:  0.863164333333
# Trial:  8  AUC:  0.864049
# Trial:  9  AUC:  0.86169
# Trial:  10  AUC:  0.863046666667
# Trial:  11  AUC:  0.863279666667
# Trial:  12  AUC:  0.864314333333
# Trial:  13  AUC:  0.864489333333
# Trial:  14  AUC:  0.864482666667
# Trial:  15  AUC:  0.864980666667
# Trial:  16  AUC:  0.863072
# (<class 'hp_gpsmbo.kernels.SqExp'>, False, 0) [(<hp_gpsmbo.kernels.SqExp object at 0x7f8f604aebd0>, slice(0, 1, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604ae850>, slice(1, 2, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604aea90>, slice(2, 3, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604aea10>, slice(4, 5, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604aecd0>, slice(7, 8, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604ae090>, slice(8, 9, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604ae2d0>, slice(9, 10, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604aeb50>, slice(10, 11, None)), (<hp_gpsmbo.kernels.SqExp object at 0x7f8f604ae890>, slice(11, 12, None))]
# 140253772573072 [(<hp_gpsmbo.kernels.ChoiceN object at 0x7f8f604ae990>, slice(3, 4, None))]
# 140253772573456 [(<hp_gpsmbo.kernels.ChoiceN object at 0x7f8f604aeb10>, slice(5, 6, None))]
# 140253772573776 [(<hp_gpsmbo.kernels.ChoiceN object at 0x7f8f604aec50>, slice(6, 7, None))]
# starting fit
# UCB: Best after 16 trials: -0.864994
# Trial:  17  AUC:  0.865025333333
# New best: 0.865025333333
# {'colsample_bytree': 0.984837788246798, 'eval_metric': 'auc', 'colsample_bylevel': 0.671214873576477, 'scale_pos_weight': 7.252198530834704, 'base_score': 0.8559152887562891, 'subsample': 0.5584686615617891, 'eta': 0.1, 'min_child_weight': 42, 'objective': 'binary:logistic', 'alpha': 12.07876745875494, 'max_depth': 9, 'gamma': 0.8391551989061872, 'lambda': 35.592981150954834}
# Trial:  17
#
# 2611.43916702
# starting fit
# UCB: Best after 17 trials: -0.865025
# Trial:  18  AUC:  0.865123666667
# New best: 0.865123666667
# {'colsample_bytree': 0.9909961477804552, 'eval_metric': 'auc', 'colsample_bylevel': 0.4631869170229841, 'scale_pos_weight': 9.991230213390715, 'base_score': 0.9393062577651421, 'subsample': 0.5275836081578824, 'eta': 0.1, 'min_child_weight': 140, 'objective': 'binary:logistic', 'alpha': 17.08476198559911, 'max_depth': 7, 'gamma': 0.21519926854680388, 'lambda': 14.333682490002944}
# Trial:  18
#
# 2630.94518995
# starting fit
# UCB: Best after 18 trials: -0.865124
# Trial:  19  AUC:  0.865208333333
# New best: 0.865208333333
# {'colsample_bytree': 0.966838110113995, 'eval_metric': 'auc', 'colsample_bylevel': 0.9129343208320142, 'scale_pos_weight': 18.58664628405264, 'base_score': 0.6253146837720448, 'subsample': 0.6297594362723558, 'eta': 0.1, 'min_child_weight': 69, 'objective': 'binary:logitraw', 'alpha': 1.9161889195769217, 'max_depth': 4, 'gamma': 1.5615780198772722, 'lambda': 2.616057058948518}
# Trial:  19
#
# 2646.45617008
# starting fit
# UCB: Best after 19 trials: -0.865208
# Trial:  20  AUC:  0.863914666667
# starting fit
# UCB: Best after 20 trials: -0.865208
# Trial:  21  AUC:  0.865601
# New best: 0.865601
# {'colsample_bytree': 0.9670721227934626, 'eval_metric': 'auc', 'colsample_bylevel': 0.9303993437810598, 'scale_pos_weight': 8.514351964996333, 'base_score': 0.5246643064671482, 'subsample': 0.6184111725045317, 'eta': 0.1, 'min_child_weight': 36, 'objective': 'binary:logitraw', 'alpha': 6.2356968871026766, 'max_depth': 4, 'gamma': 1.795279148704355, 'lambda': 5.218602828371909}
# Trial:  21
#
# 2678.77496791
# starting fit
# UCB: Best after 21 trials: -0.865601
# Trial:  22  AUC:  0.865525666667
# starting fit
# UCB: Best after 22 trials: -0.865601
# Trial:  23  AUC:  0.865531333333
# starting fit
# UCB: Best after 23 trials: -0.865601
# Trial:  24  AUC:  0.866013666667
# New best: 0.866013666667
# {'colsample_bytree': 0.9642509592612922, 'eval_metric': 'auc', 'colsample_bylevel': 0.9999, 'scale_pos_weight': 4.291887302904624, 'base_score': 0.35905545651759174, 'subsample': 0.595746749698778, 'eta': 0.1, 'min_child_weight': 47, 'objective': 'binary:logitraw', 'alpha': 9.611379559458406, 'max_depth': 4, 'gamma': 2.0958524947151456, 'lambda': 9.71798699550904}
# Trial:  24
#
# 2729.91874099
# starting fit
# UCB: Best after 24 trials: -0.866014
# Trial:  25  AUC:  0.5
# starting fit
# UCB: Best after 25 trials: -0.866014
# Trial:  26  AUC:  0.864626333333
# starting fit
# UCB: Best after 26 trials: -0.866014
# Trial:  27  AUC:  0.865501666667
# starting fit
# UCB: Best after 27 trials: -0.866014
# Trial:  28  AUC:  0.860189666667
# starting fit
# UCB: Best after 28 trials: -0.866014
# Trial:  29  AUC:  0.864142333333
# starting fit
# UCB: Best after 29 trials: -0.866014
# Trial:  30  AUC:  0.858667333333
# starting fit
# UCB: Best after 30 trials: -0.866014
# Trial:  31  AUC:  0.865648666667
# starting fit
# UCB: Best after 31 trials: -0.866014
# Trial:  32  AUC:  0.5
# starting fit
# UCB: Best after 32 trials: -0.866014
# Trial:  33  AUC:  0.863765333333
# starting fit
# UCB: Best after 33 trials: -0.866014
# Trial:  34  AUC:  0.865132333333
# starting fit
# UCB: Best after 34 trials: -0.866014
# Trial:  35  AUC:  0.864673333333
# starting fit
# UCB: Best after 35 trials: -0.866014
# Trial:  36  AUC:  0.744421
# starting fit
# UCB: Best after 36 trials: -0.866014
# Trial:  37  AUC:  0.865060666667
# starting fit
# UCB: Best after 37 trials: -0.866014
# Trial:  38  AUC:  0.864843
# starting fit
# UCB: Best after 38 trials: -0.866014
# Trial:  39  AUC:  0.5
# starting fit
# UCB: Best after 39 trials: -0.866014
# Trial:  40  AUC:  0.5
# starting fit
# UCB: Best after 40 trials: -0.866014
# Trial:  41  AUC:  0.862849333333
# starting fit
# UCB: Best after 41 trials: -0.866014
# Trial:  42  AUC:  0.864903333333
# starting fit
# UCB: Best after 42 trials: -0.866014
# Trial:  43  AUC:  0.865097333333
# starting fit
# UCB: Best after 43 trials: -0.866014
# Trial:  44  AUC:  0.865837666667
# starting fit
# UCB: Best after 44 trials: -0.866014
# Trial:  45  AUC:  0.865743
# starting fit
# UCB: Best after 45 trials: -0.866014
# Trial:  46  AUC:  0.863497666667
# starting fit
# UCB: Best after 46 trials: -0.866014
# Trial:  47  AUC:  0.865858333333
# starting fit
# UCB: Best after 47 trials: -0.866014
# Trial:  48  AUC:  0.860704666667
# starting fit
# UCB: Best after 48 trials: -0.866014
# Trial:  49  AUC:  0.865102333333
# starting fit
# UCB: Best after 49 trials: -0.866014
# Trial:  50  AUC:  0.860534666667
# starting fit
# UCB: Best after 50 trials: -0.866014
# Trial:  51  AUC:  0.864488333333
# starting fit
# UCB: Best after 51 trials: -0.866014
# Trial:  52  AUC:  0.5
# starting fit
# UCB: Best after 52 trials: -0.866014
# Trial:  53  AUC:  0.864049
# starting fit
# UCB: Best after 53 trials: -0.866014
# Trial:  54  AUC:  0.865318
# starting fit
# UCB: Best after 54 trials: -0.866014
# Trial:  55  AUC:  0.865491
# starting fit
# UCB: Best after 55 trials: -0.866014
# Trial:  56  AUC:  0.865653666667
# starting fit
# UCB: Best after 56 trials: -0.866014
# Trial:  57  AUC:  0.864952666667
# starting fit
# UCB: Best after 57 trials: -0.866014
# Trial:  58  AUC:  0.865379666667
# starting fit
# UCB: Best after 58 trials: -0.866014
# Trial:  59  AUC:  0.865455333333
# starting fit
# UCB: Best after 59 trials: -0.866014
# Trial:  60  AUC:  0.865906
# starting fit
# UCB: Best after 60 trials: -0.866014
# Trial:  61  AUC:  0.863238
# starting fit
# UCB: Best after 61 trials: -0.866014
# Trial:  62  AUC:  0.865476
# starting fit
# UCB: Best after 62 trials: -0.866014
# Trial:  63  AUC:  0.865417333333
# starting fit
# UCB: Best after 63 trials: -0.866014
# Trial:  64  AUC:  0.865158666667
# starting fit
# UCB: Best after 64 trials: -0.866014
# Trial:  65  AUC:  0.865088333333
# starting fit
# UCB: Best after 65 trials: -0.866014
# Trial:  66  AUC:  0.864925333333
# starting fit
# UCB: Best after 66 trials: -0.866014
# Trial:  67  AUC:  0.864455666667
# starting fit
# UCB: Best after 67 trials: -0.866014
# Trial:  68  AUC:  0.865512
# starting fit
# UCB: Best after 68 trials: -0.866014
# Trial:  69  AUC:  0.865225333333
# starting fit
# UCB: Best after 69 trials: -0.866014
# Trial:  70  AUC:  0.865111666667
# starting fit
# UCB: Best after 70 trials: -0.866014
# Trial:  71  AUC:  0.865336666667
# starting fit
# UCB: Best after 71 trials: -0.866014
# Trial:  72  AUC:  0.865347333333
# starting fit
# UCB: Best after 72 trials: -0.866014
# Trial:  73  AUC:  0.865348666667
# starting fit
# UCB: Best after 73 trials: -0.866014
# Trial:  74  AUC:  0.864899
# starting fit
# UCB: Best after 74 trials: -0.866014
# Trial:  75  AUC:  0.865643333333
# starting fit
# UCB: Best after 75 trials: -0.866014
# Trial:  76  AUC:  0.863199333333
# starting fit
# UCB: Best after 76 trials: -0.866014
# Trial:  77  AUC:  0.865145666667
# starting fit
# UCB: Best after 77 trials: -0.866014
# Trial:  78  AUC:  0.865122
# starting fit
# UCB: Best after 78 trials: -0.866014
# Trial:  79  AUC:  0.860364333333
# starting fit
# UCB: Best after 79 trials: -0.866014
# Trial:  80  AUC:  0.862457333333
# starting fit
# UCB: Best after 80 trials: -0.866014
# Trial:  81  AUC:  0.865703333333
# starting fit
# UCB: Best after 81 trials: -0.866014
# Trial:  82  AUC:  0.864607
# starting fit
# UCB: Best after 82 trials: -0.866014
# Trial:  83  AUC:  0.865807666667
# starting fit
# UCB: Best after 83 trials: -0.866014
# Trial:  84  AUC:  0.864408
# starting fit
# UCB: Best after 84 trials: -0.866014
# Trial:  85  AUC:  0.5
# starting fit
# UCB: Best after 85 trials: -0.866014
# Trial:  86  AUC:  0.862814
# starting fit
# UCB: Best after 86 trials: -0.866014
# Trial:  87  AUC:  0.863818
# starting fit
# UCB: Best after 87 trials: -0.866014
# Trial:  88  AUC:  0.864722333333
# starting fit
# UCB: Best after 88 trials: -0.866014
# Trial:  89  AUC:  0.863339333333
# starting fit
# UCB: Best after 89 trials: -0.866014
# Trial:  90  AUC:  0.863761666667
# starting fit
# UCB: Best after 90 trials: -0.866014
# Trial:  91  AUC:  0.5
# starting fit
# UCB: Best after 91 trials: -0.866014
# Trial:  92  AUC:  0.863568333333
# starting fit
# UCB: Best after 92 trials: -0.866014
# Trial:  93  AUC:  0.865301333333
# starting fit
# UCB: Best after 93 trials: -0.866014
# Trial:  94  AUC:  0.865006
# starting fit
# UCB: Best after 94 trials: -0.866014
# Trial:  95  AUC:  0.5
# starting fit
# UCB: Best after 95 trials: -0.866014
# Trial:  96  AUC:  0.864700666667
# starting fit
# UCB: Best after 96 trials: -0.866014
# Trial:  97  AUC:  0.5
# starting fit
# UCB: Best after 97 trials: -0.866014
# Trial:  98  AUC:  0.5
# starting fit
# UCB: Best after 98 trials: -0.866014
# Trial:  99  AUC:  0.865475333333
# starting fit
# UCB: Best after 99 trials: -0.866014
# Trial:  100  AUC:  0.863640666667
# starting fit
# UCB: Best after 100 trials: -0.866014
# Trial:  101  AUC:  0.865015666667
# starting fit
# UCB: Best after 101 trials: -0.866014
# Trial:  102  AUC:  0.864917333333
# starting fit
# UCB: Best after 102 trials: -0.866014
# Trial:  103  AUC:  0.864534666667
# starting fit
# UCB: Best after 103 trials: -0.866014
# Trial:  104  AUC:  0.865573666667
# starting fit
# UCB: Best after 104 trials: -0.866014
# Trial:  105  AUC:  0.865292333333
# starting fit
# UCB: Best after 105 trials: -0.866014
# Trial:  106  AUC:  0.865327
# starting fit
# UCB: Best after 106 trials: -0.866014
# Trial:  107  AUC:  0.865001666667
# starting fit
# UCB: Best after 107 trials: -0.866014
# Trial:  108  AUC:  0.863287666667
# starting fit
# UCB: Best after 108 trials: -0.866014
# Trial:  109  AUC:  0.861673666667
# starting fit
# UCB: Best after 109 trials: -0.866014
# Trial:  110  AUC:  0.864408333333
# starting fit
# UCB: Best after 110 trials: -0.866014
# Trial:  111  AUC:  0.862426
# starting fit
# UCB: Best after 111 trials: -0.866014
# Trial:  112  AUC:  0.865028
# starting fit
# UCB: Best after 112 trials: -0.866014
# Trial:  113  AUC:  0.862648666667
# starting fit
# UCB: Best after 113 trials: -0.866014
# Trial:  114  AUC:  0.5
# starting fit
# UCB: Best after 114 trials: -0.866014
# Trial:  115  AUC:  0.865220333333
# starting fit
# UCB: Best after 115 trials: -0.866014
# Trial:  116  AUC:  0.864795333333
# starting fit
# UCB: Best after 116 trials: -0.866014
# Trial:  117  AUC:  0.5
# starting fit
# UCB: Best after 117 trials: -0.866014
# Trial:  118  AUC:  0.863795
# starting fit
# UCB: Best after 118 trials: -0.866014
# Trial:  119  AUC:  0.5
# starting fit
# UCB: Best after 119 trials: -0.866014
# Trial:  120  AUC:  0.865202333333
# starting fit
# UCB: Best after 120 trials: -0.866014
# Trial:  121  AUC:  0.865539
# starting fit
# UCB: Best after 121 trials: -0.866014
# Trial:  122  AUC:  0.862473
# starting fit
# UCB: Best after 122 trials: -0.866014
# Trial:  123  AUC:  0.864874
# starting fit
# UCB: Best after 123 trials: -0.866014
# Trial:  124  AUC:  0.865408
# starting fit
# UCB: Best after 124 trials: -0.866014
# Trial:  125  AUC:  0.852675666667
# Best Estimator:  {'colsample_bytree': 0.9642509592612922, 'eval_metric': 'auc', 'colsample_bylevel': 0.9999, 'scale_pos_weight': 4.291887302904624, 'base_score': 0.35905545651759174, 'subsample': 0.595746749698778, 'eta': 0.1, 'min_child_weight': 47, 'objective': 'binary:logitraw', 'alpha': 9.611379559458406, 'max_depth': 4, 'gamma': 2.0958524947151456, 'lambda': 9.71798699550904}

# %% [markdown]
# ### Find optimal number of estimators

# %%
modelcvBO=xgb.cv(paramsBO, xgtrain, 10000, nfold=10, early_stopping_rounds=125)
modelcvBOBC=xgb.cv(paramsBOBC, xgtrain_bc, 10000, nfold=10, early_stopping_rounds=125)

# print cv results
print '10-fold CV'
print 'Cross-Validation Results for NON-Box-Cox Transformed'
print modelcvBO.iloc[-1]
print '-'*57
print 'Cross-Validation Results for Box-Cox Transformed'
print modelcvBOBC.iloc[-1]
# Out:
# 10-fold CV
# Cross-Validation Results for NON-Box-Cox Transformed
# test-auc-mean     0.866842
# test-auc-std      0.008541
# train-auc-mean    0.877029
# train-auc-std     0.000964
# Name: 146, dtype: float64
# ---------------------------------------------------------
# Cross-Validation Results for Box-Cox Transformed
# test-auc-mean     0.866553
# test-auc-std      0.008509
# train-auc-mean    0.874583
# train-auc-std     0.000951
# Name: 122, dtype: float64

# %% [markdown]
# ### Fit Optimized Models

# %%
#fit
model=xgb.train(paramsBO, xgtrain, np.size(modelcvBO,0))
modelbc=xgb.train(paramsBOBC, xgtrain_bc, np.size(modelcvBOBC,0))

# %% [markdown]
# ### Plot Tree

# %%
xgb.to_graphviz(model,num_trees=0)

# %% [markdown]
# ### Make and Store Submissions

# %%
# predict and store unmodified X
pred=model.predict(xgtest)
submission = pd.DataFrame()
submission['Probability'] = pred
submission.to_csv('sub_v.csv')


# predict and store Box-cox X
pred=modelbc.predict(xgtest_bc)
predp=np.exp(pred)/(1+np.exp(pred))
submission = pd.DataFrame()
submission['Probability'] = predp
submission.to_csv('sub_v_BC.csv')

# %%
print
print 'XGBoost Optimized, No Independent Variable Transformation'
XGBoost_url3= 'http://i.imgur.com/uPNAuUF.jpg'
Image(url=XGBoost_url3)
# Out:
# XGBoost Optimized, No Independent Variable Transformation
# <img src="http://i.imgur.com/uPNAuUF.jpg"/>

# %%
print
print 'XGBoost Optimized, Box-Cox Independent Variable Transformation'
XGBoost_url4 = 'http://i.imgur.com/M39CJOD.jpg'
Image(url=XGBoost_url4)
# Out:
# XGBoost Optimized, Box-Cox Independent Variable Transformation
# <img src="http://i.imgur.com/M39CJOD.jpg"/>
